# %% [markdown]
# ## Markdown in Jupyter Notebook
#
# ### Practice Markdown here - https://commonmark.org/help/
# Markdown is a simple way to format text that looks great on any device.
#
# Markdown is a simple way to format text that looks great on any device.
#
# *Markdown is a simple way to format text that looks great on any device*
#
# **Markdown is a simple way to format text that looks great on any device.**
#
# *_Markdown is a simple way to format text that looks great on any device._*
#
# __Markdown is a simple way to format text that looks great on any device.__

# %% [markdown]
# # 1. Python programming
# ## 1.1 Python programming
# ### 1.1.1 Python programming
# #### 1.1.1.a Python programming
# ##### 1.1.1.a.i Python programming
# https://en.wikipedia.org/wiki/Markdown
#
# Markdown Wiki

# %% [markdown]
# ## Markdown Wiki
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# > My favorite language for maintainability is Python. It has simple, clean syntax, object encapsulation, good library support, and optional named parameters
#
#
# -Bram Cohen
#
# - list item
# - list item
# - list item
# - list item
# - list item
# - list item
# - list item
# - list item
# - list item

# %%
print('-'*250)
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Markdown `is` a `simple` way to `format` text.
#
#
# #### Code block:

# %%
print('Hello World!')
print('Hello World!')
def kilometre_1(km):  
    conversion_ratio_1= 0.621371  
    miles_1 = km * conversion_ratio_1  
    print ("The speed value of car in Miles: ", miles_1)  
km = float (input ("Please enter the speed of car in Kilometre as a unit: "))  
kilometre_1(km)
def kilometre_1(km):
conversion_ratio_1= 0.621371
miles_1 = km * conversion_ratio_1
print ("The speed value of car in Miles: ", miles_1)
km = float (input ("Please enter the speed of car in Kilometre as a unit: "))
kilometre_1(km)
# Out:
#   Input In [6]
#     conversion_ratio_1= 0.621371
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# **Varsha**
#
# __varsha__
#
# *Varsha*
#
# _Varsha_

# %% [markdown]
# *Python*
# **Python**
# ***Python***

# %% [markdown]
# # varsha
# ## varsha
# ### varsha
# # Divya
